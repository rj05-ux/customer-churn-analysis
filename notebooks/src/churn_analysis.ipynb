# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load Data

# %%
df = pd.read_csv("/workspaces/customer-churn-analysis/data/dataset.csv")

# %% [markdown]
# Recreate Churn

# %%
import numpy as np
df['churn'] = np.where(df['days_since_last_purchase'] > 90, 1, 0)
